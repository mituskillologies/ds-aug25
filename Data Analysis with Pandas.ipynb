# %%
import pandas as pd

# %% [markdown]
# ##### Series

# %%
s = pd.Series([45,12,32,76,38,29,19,42])

# %%
s
# Out:
# 0    45
# 1    12
# 2    32
# 3    76
# 4    38
# 5    29
# 6    19
# 7    42
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.dtype
# Out:
# dtype('int64')

# %%
import numpy as np

# %%
s = pd.Series([45,12,32,76,38,29,19,42], dtype = np.int8)
s
# Out:
# 0    45
# 1    12
# 2    32
# 3    76
# 4    38
# 5    29
# 6    19
# 7    42
# dtype: int8

# %%
s[4]
# Out:
# 38

# %%
s[4] = 49

# %%
s
# Out:
# 0    45
# 1    12
# 2    32
# 3    76
# 4    49
# 5    29
# 6    19
# 7    42
# dtype: int8

# %%
s = pd.Series([45, 12, 32.67, 76, 38, 29.18, 19, 42])

# %%
s
# Out:
# 0    45.00
# 1    12.00
# 2    32.67
# 3    76.00
# 4    38.00
# 5    29.18
# 6    19.00
# 7    42.00
# dtype: float64

# %%
s.min()
# Out:
# 12.0

# %%
s.max()
# Out:
# 76.0

# %%
s.mean()
# Out:
# 36.73125

# %%
s.std()
# Out:
# 19.417677834900854

# %%
s.sum()
# Out:
# 293.85

# %% [markdown]
# ##### DataFrame

# %%
s1 = pd.Series([1,2,3,4,5])
s2 = pd.Series(['riya','anil','prem','rajat','karan'])
s3 = pd.Series([56.89, 67.34, 72.76, 62.47, 81.45])

# %%
df = pd.DataFrame({
    'roll': s1,
    'name': s2,
    'marks': s3
})

# %%
df
# Out:
#    roll   name  marks
# 0     1   riya  56.89
# 1     2   anil  67.34
# 2     3   prem  72.76
# 3     4  rajat  62.47
# 4     5  karan  81.45

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (5, 3)

# %%
df.columns
# Out:
# Index(['roll', 'name', 'marks'], dtype='object')

# %%
df.dtypes
# Out:
# roll       int64
# name      object
# marks    float64
# dtype: object

# %% [markdown]
# ##### Working with dataset

# %%
# Location: https://mitu.co.in/dataset
# Download student-info.csv and save in current working directory

# %%
# How to find current working directory?
import os
os.getcwd()
# Out:
# '/home/mitu/programs/ml/ds-sep25'

# %%
# import the data
df = pd.read_csv("student-info.csv")

# %%
df
# Out:
#     roll              name class  marks  age
# 0      1   Aditya Kulkarni    FY   85.5   15
# 1      2     Swapnil Joshi    FY   92.1   16
# 2      3  Aniket Deshpande    FY   78.3   16
# 3      4       Gauri Patil    FY   65.8   16
# 4      5      Rohan Sawant    FY   88.2   17
# 5      6        Pooja More    FY   72.9   16
# 6      7    Shreyas Shinde    FY   95.0   16
# 7      8      Sneha Jadhav    FY   58.6   15
# 8      9      Mahesh Pawar    FY   76.4   16
# 9     10      Priya Chavan    FY   89.7   15
# 10    11      Amruta Kadam    SY   91.2   17
# 11    12      Sandeep Mane    SY   68.5   17
# 12    13      Neha Gaikwad    SY   79.9   17
# 13    14       Sachin Kale    SY   83.1   18
# 14    15      Manisha Rane    SY   94.6   18
# 15    16      Prasad Desai    SY   61.3   17
# 16    17      Aditi Phadke    SY   77.8   16
# 17    18      Sameer Tambe    SY   82.0   18
# 18    19       Reshma Apte    SY   90.4   17
# 19    20     Kiran Godbole    SY   73.7   16
# 20    21    Archana Ingale    TY   55.1   19
# 21    22     Vivek Bhosale    TY   66.9   17
# 22    23     Sonali Kamble    TY   96.2   17
# 23    24    Harshal Shelar    TY   71.5   19
# 24    25   Prachi Deshmukh    TY   48.8   19
# 25    26      Milind Patil    TY   84.3   18
# 26    27     Rohini Sawant    TY   59.7   18
# 27    28   Yogesh Kulkarni    TY   93.0   18
# 28    29  Supriya Waghmare    TY   67.2   19
# 29    30      Girish Joshi    TY   75.6   19

# %%
# rows and columns
df.shape
# Out:
# (30, 5)

# %%
# names of columns
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
df.dtypes
# Out:
# roll       int64
# name      object
# class     object
# marks    float64
# age        int64
# dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ##### Data Slicing

# %%
# iloc needs row sequence and column sequence
df.iloc[5:13,1:4]
# Out:
#               name class  marks
# 5       Pooja More    FY   72.9
# 6   Shreyas Shinde    FY   95.0
# 7     Sneha Jadhav    FY   58.6
# 8     Mahesh Pawar    FY   76.4
# 9     Priya Chavan    FY   89.7
# 10    Amruta Kadam    SY   91.2
# 11    Sandeep Mane    SY   68.5
# 12    Neha Gaikwad    SY   79.9

# %%
x = df.iloc[5:13,1:4]
x
# Out:
#               name class  marks
# 5       Pooja More    FY   72.9
# 6   Shreyas Shinde    FY   95.0
# 7     Sneha Jadhav    FY   58.6
# 8     Mahesh Pawar    FY   76.4
# 9     Priya Chavan    FY   89.7
# 10    Amruta Kadam    SY   91.2
# 11    Sandeep Mane    SY   68.5
# 12    Neha Gaikwad    SY   79.9

# %%
df.iloc[:13,1:4]
# Out:
#                 name class  marks
# 0    Aditya Kulkarni    FY   85.5
# 1      Swapnil Joshi    FY   92.1
# 2   Aniket Deshpande    FY   78.3
# 3        Gauri Patil    FY   65.8
# 4       Rohan Sawant    FY   88.2
# 5         Pooja More    FY   72.9
# 6     Shreyas Shinde    FY   95.0
# 7       Sneha Jadhav    FY   58.6
# 8       Mahesh Pawar    FY   76.4
# 9       Priya Chavan    FY   89.7
# 10      Amruta Kadam    SY   91.2
# 11      Sandeep Mane    SY   68.5
# 12      Neha Gaikwad    SY   79.9

# %%
df.iloc[6:13,1:]
# Out:
#               name class  marks  age
# 6   Shreyas Shinde    FY   95.0   16
# 7     Sneha Jadhav    FY   58.6   15
# 8     Mahesh Pawar    FY   76.4   16
# 9     Priya Chavan    FY   89.7   15
# 10    Amruta Kadam    SY   91.2   17
# 11    Sandeep Mane    SY   68.5   17
# 12    Neha Gaikwad    SY   79.9   17

# %%
df.iloc[22:,1:]
# Out:
#                 name class  marks  age
# 22     Sonali Kamble    TY   96.2   17
# 23    Harshal Shelar    TY   71.5   19
# 24   Prachi Deshmukh    TY   48.8   19
# 25      Milind Patil    TY   84.3   18
# 26     Rohini Sawant    TY   59.7   18
# 27   Yogesh Kulkarni    TY   93.0   18
# 28  Supriya Waghmare    TY   67.2   19
# 29      Girish Joshi    TY   75.6   19

# %%
df.iloc[[2,6,12,15,25],[1,3]]
# Out:
#                 name  marks
# 2   Aniket Deshpande   78.3
# 6     Shreyas Shinde   95.0
# 12      Neha Gaikwad   79.9
# 15      Prasad Desai   61.3
# 25      Milind Patil   84.3

# %%
df.loc[:,'name']
# Out:
# 0      Aditya Kulkarni
# 1        Swapnil Joshi
# 2     Aniket Deshpande
# 3          Gauri Patil
# 4         Rohan Sawant
# 5           Pooja More
# 6       Shreyas Shinde
# 7         Sneha Jadhav
# 8         Mahesh Pawar
# 9         Priya Chavan
# 10        Amruta Kadam
# 11        Sandeep Mane
# 12        Neha Gaikwad
# 13         Sachin Kale
# 14        Manisha Rane
# 15        Prasad Desai
# 16        Aditi Phadke
# 17        Sameer Tambe
# 18         Reshma Apte
# 19       Kiran Godbole
# 20      Archana Ingale
# 21       Vivek Bhosale
# 22       Sonali Kamble
# 23      Harshal Shelar
# 24     Prachi Deshmukh
# 25        Milind Patil
# 26       Rohini Sawant
# 27     Yogesh Kulkarni
# 28    Supriya Waghmare
# 29        Girish Joshi
# Name: name, dtype: object

# %%
df.loc[:,['name','marks']]
# Out:
#                 name  marks
# 0    Aditya Kulkarni   85.5
# 1      Swapnil Joshi   92.1
# 2   Aniket Deshpande   78.3
# 3        Gauri Patil   65.8
# 4       Rohan Sawant   88.2
# 5         Pooja More   72.9
# 6     Shreyas Shinde   95.0
# 7       Sneha Jadhav   58.6
# 8       Mahesh Pawar   76.4
# 9       Priya Chavan   89.7
# 10      Amruta Kadam   91.2
# 11      Sandeep Mane   68.5
# 12      Neha Gaikwad   79.9
# 13       Sachin Kale   83.1
# 14      Manisha Rane   94.6
# 15      Prasad Desai   61.3
# 16      Aditi Phadke   77.8
# 17      Sameer Tambe   82.0
# 18       Reshma Apte   90.4
# 19     Kiran Godbole   73.7
# 20    Archana Ingale   55.1
# 21     Vivek Bhosale   66.9
# 22     Sonali Kamble   96.2
# 23    Harshal Shelar   71.5
# 24   Prachi Deshmukh   48.8
# 25      Milind Patil   84.3
# 26     Rohini Sawant   59.7
# 27   Yogesh Kulkarni   93.0
# 28  Supriya Waghmare   67.2
# 29      Girish Joshi   75.6

# %%
df['name']
# Out:
# 0      Aditya Kulkarni
# 1        Swapnil Joshi
# 2     Aniket Deshpande
# 3          Gauri Patil
# 4         Rohan Sawant
# 5           Pooja More
# 6       Shreyas Shinde
# 7         Sneha Jadhav
# 8         Mahesh Pawar
# 9         Priya Chavan
# 10        Amruta Kadam
# 11        Sandeep Mane
# 12        Neha Gaikwad
# 13         Sachin Kale
# 14        Manisha Rane
# 15        Prasad Desai
# 16        Aditi Phadke
# 17        Sameer Tambe
# 18         Reshma Apte
# 19       Kiran Godbole
# 20      Archana Ingale
# 21       Vivek Bhosale
# 22       Sonali Kamble
# 23      Harshal Shelar
# 24     Prachi Deshmukh
# 25        Milind Patil
# 26       Rohini Sawant
# 27     Yogesh Kulkarni
# 28    Supriya Waghmare
# 29        Girish Joshi
# Name: name, dtype: object

# %%
df[['name','marks']]
# Out:
#                 name  marks
# 0    Aditya Kulkarni   85.5
# 1      Swapnil Joshi   92.1
# 2   Aniket Deshpande   78.3
# 3        Gauri Patil   65.8
# 4       Rohan Sawant   88.2
# 5         Pooja More   72.9
# 6     Shreyas Shinde   95.0
# 7       Sneha Jadhav   58.6
# 8       Mahesh Pawar   76.4
# 9       Priya Chavan   89.7
# 10      Amruta Kadam   91.2
# 11      Sandeep Mane   68.5
# 12      Neha Gaikwad   79.9
# 13       Sachin Kale   83.1
# 14      Manisha Rane   94.6
# 15      Prasad Desai   61.3
# 16      Aditi Phadke   77.8
# 17      Sameer Tambe   82.0
# 18       Reshma Apte   90.4
# 19     Kiran Godbole   73.7
# 20    Archana Ingale   55.1
# 21     Vivek Bhosale   66.9
# 22     Sonali Kamble   96.2
# 23    Harshal Shelar   71.5
# 24   Prachi Deshmukh   48.8
# 25      Milind Patil   84.3
# 26     Rohini Sawant   59.7
# 27   Yogesh Kulkarni   93.0
# 28  Supriya Waghmare   67.2
# 29      Girish Joshi   75.6

# %%
df.head()
# Out:
#    roll              name class  marks  age
# 0     1   Aditya Kulkarni    FY   85.5   15
# 1     2     Swapnil Joshi    FY   92.1   16
# 2     3  Aniket Deshpande    FY   78.3   16
# 3     4       Gauri Patil    FY   65.8   16
# 4     5      Rohan Sawant    FY   88.2   17

# %%
df.head(3)
# Out:
#    roll              name class  marks  age
# 0     1   Aditya Kulkarni    FY   85.5   15
# 1     2     Swapnil Joshi    FY   92.1   16
# 2     3  Aniket Deshpande    FY   78.3   16

# %%
df.tail()
# Out:
#     roll              name class  marks  age
# 25    26      Milind Patil    TY   84.3   18
# 26    27     Rohini Sawant    TY   59.7   18
# 27    28   Yogesh Kulkarni    TY   93.0   18
# 28    29  Supriya Waghmare    TY   67.2   19
# 29    30      Girish Joshi    TY   75.6   19

# %%
df.tail(3)
# Out:
#     roll              name class  marks  age
# 27    28   Yogesh Kulkarni    TY   93.0   18
# 28    29  Supriya Waghmare    TY   67.2   19
# 29    30      Girish Joshi    TY   75.6   19

# %%
df.drop(5)
# Out:
#     roll              name class  marks  age
# 0      1   Aditya Kulkarni    FY   85.5   15
# 1      2     Swapnil Joshi    FY   92.1   16
# 2      3  Aniket Deshpande    FY   78.3   16
# 3      4       Gauri Patil    FY   65.8   16
# 4      5      Rohan Sawant    FY   88.2   17
# 6      7    Shreyas Shinde    FY   95.0   16
# 7      8      Sneha Jadhav    FY   58.6   15
# 8      9      Mahesh Pawar    FY   76.4   16
# 9     10      Priya Chavan    FY   89.7   15
# 10    11      Amruta Kadam    SY   91.2   17
# 11    12      Sandeep Mane    SY   68.5   17
# 12    13      Neha Gaikwad    SY   79.9   17
# 13    14       Sachin Kale    SY   83.1   18
# 14    15      Manisha Rane    SY   94.6   18
# 15    16      Prasad Desai    SY   61.3   17
# 16    17      Aditi Phadke    SY   77.8   16
# 17    18      Sameer Tambe    SY   82.0   18
# 18    19       Reshma Apte    SY   90.4   17
# 19    20     Kiran Godbole    SY   73.7   16
# 20    21    Archana Ingale    TY   55.1   19
# 21    22     Vivek Bhosale    TY   66.9   17
# 22    23     Sonali Kamble    TY   96.2   17
# 23    24    Harshal Shelar    TY   71.5   19
# 24    25   Prachi Deshmukh    TY   48.8   19
# 25    26      Milind Patil    TY   84.3   18
# 26    27     Rohini Sawant    TY   59.7   18
# 27    28   Yogesh Kulkarni    TY   93.0   18
# 28    29  Supriya Waghmare    TY   67.2   19
# 29    30      Girish Joshi    TY   75.6   19

# %%
df.drop([2,6,12,23])
# Out:
#     roll              name class  marks  age
# 0      1   Aditya Kulkarni    FY   85.5   15
# 1      2     Swapnil Joshi    FY   92.1   16
# 3      4       Gauri Patil    FY   65.8   16
# 4      5      Rohan Sawant    FY   88.2   17
# 5      6        Pooja More    FY   72.9   16
# 7      8      Sneha Jadhav    FY   58.6   15
# 8      9      Mahesh Pawar    FY   76.4   16
# 9     10      Priya Chavan    FY   89.7   15
# 10    11      Amruta Kadam    SY   91.2   17
# 11    12      Sandeep Mane    SY   68.5   17
# 13    14       Sachin Kale    SY   83.1   18
# 14    15      Manisha Rane    SY   94.6   18
# 15    16      Prasad Desai    SY   61.3   17
# 16    17      Aditi Phadke    SY   77.8   16
# 17    18      Sameer Tambe    SY   82.0   18
# 18    19       Reshma Apte    SY   90.4   17
# 19    20     Kiran Godbole    SY   73.7   16
# 20    21    Archana Ingale    TY   55.1   19
# 21    22     Vivek Bhosale    TY   66.9   17
# 22    23     Sonali Kamble    TY   96.2   17
# 24    25   Prachi Deshmukh    TY   48.8   19
# 25    26      Milind Patil    TY   84.3   18
# 26    27     Rohini Sawant    TY   59.7   18
# 27    28   Yogesh Kulkarni    TY   93.0   18
# 28    29  Supriya Waghmare    TY   67.2   19
# 29    30      Girish Joshi    TY   75.6   19

# %%
df.drop('class', axis = 1)
# Out:
#     roll              name  marks  age
# 0      1   Aditya Kulkarni   85.5   15
# 1      2     Swapnil Joshi   92.1   16
# 2      3  Aniket Deshpande   78.3   16
# 3      4       Gauri Patil   65.8   16
# 4      5      Rohan Sawant   88.2   17
# 5      6        Pooja More   72.9   16
# 6      7    Shreyas Shinde   95.0   16
# 7      8      Sneha Jadhav   58.6   15
# 8      9      Mahesh Pawar   76.4   16
# 9     10      Priya Chavan   89.7   15
# 10    11      Amruta Kadam   91.2   17
# 11    12      Sandeep Mane   68.5   17
# 12    13      Neha Gaikwad   79.9   17
# 13    14       Sachin Kale   83.1   18
# 14    15      Manisha Rane   94.6   18
# 15    16      Prasad Desai   61.3   17
# 16    17      Aditi Phadke   77.8   16
# 17    18      Sameer Tambe   82.0   18
# 18    19       Reshma Apte   90.4   17
# 19    20     Kiran Godbole   73.7   16
# 20    21    Archana Ingale   55.1   19
# 21    22     Vivek Bhosale   66.9   17
# 22    23     Sonali Kamble   96.2   17
# 23    24    Harshal Shelar   71.5   19
# 24    25   Prachi Deshmukh   48.8   19
# 25    26      Milind Patil   84.3   18
# 26    27     Rohini Sawant   59.7   18
# 27    28   Yogesh Kulkarni   93.0   18
# 28    29  Supriya Waghmare   67.2   19
# 29    30      Girish Joshi   75.6   19

# %%
df.drop(['class','age'], axis = 1)
# Out:
#     roll              name  marks
# 0      1   Aditya Kulkarni   85.5
# 1      2     Swapnil Joshi   92.1
# 2      3  Aniket Deshpande   78.3
# 3      4       Gauri Patil   65.8
# 4      5      Rohan Sawant   88.2
# 5      6        Pooja More   72.9
# 6      7    Shreyas Shinde   95.0
# 7      8      Sneha Jadhav   58.6
# 8      9      Mahesh Pawar   76.4
# 9     10      Priya Chavan   89.7
# 10    11      Amruta Kadam   91.2
# 11    12      Sandeep Mane   68.5
# 12    13      Neha Gaikwad   79.9
# 13    14       Sachin Kale   83.1
# 14    15      Manisha Rane   94.6
# 15    16      Prasad Desai   61.3
# 16    17      Aditi Phadke   77.8
# 17    18      Sameer Tambe   82.0
# 18    19       Reshma Apte   90.4
# 19    20     Kiran Godbole   73.7
# 20    21    Archana Ingale   55.1
# 21    22     Vivek Bhosale   66.9
# 22    23     Sonali Kamble   96.2
# 23    24    Harshal Shelar   71.5
# 24    25   Prachi Deshmukh   48.8
# 25    26      Milind Patil   84.3
# 26    27     Rohini Sawant   59.7
# 27    28   Yogesh Kulkarni   93.0
# 28    29  Supriya Waghmare   67.2
# 29    30      Girish Joshi   75.6

# %% [markdown]
# ##### Descriptive Operations on data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    30 non-null     int64
#  1   name    30 non-null     object
#  2   class   30 non-null     object
#  3   marks   30 non-null     float64
#  4   age     30 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.3+ KB

# %%
df.describe()
# Out:
#             roll      marks        age
# count  30.000000  30.000000  30.000000
# mean   15.500000  77.443333  17.066667
# std     8.803408  13.080828   1.257620
# min     1.000000  48.800000  15.000000
# 25%     8.250000  67.525000  16.000000
# 50%    15.500000  78.050000  17.000000
# 75%    22.750000  89.325000  18.000000
# max    30.000000  96.200000  19.000000

# %%
df['marks'].count()
# Out:
# 30

# %%
df['marks'].max()
# Out:
# 96.2

# %%
df['marks'].min()
# Out:
# 48.8

# %%
df['marks'].sum()
# Out:
# 2323.2999999999997

# %%
df['marks'].median()
# Out:
# 78.05

# %%
df['marks'].mean()
# Out:
# 77.44333333333333

# %%
df.max()
# Out:
# roll                  30
# name     Yogesh Kulkarni
# class                 TY
# marks               96.2
# age                   19
# dtype: object

# %%
df.mean(numeric_only=True)
# Out:
# roll     15.500000
# marks    77.443333
# age      17.066667
# dtype: float64

# %% [markdown]
# ##### Custom Column operations

# %%
df['roll'] + 100
# Out:
# 0     101
# 1     102
# 2     103
# 3     104
# 4     105
# 5     106
# 6     107
# 7     108
# 8     109
# 9     110
# 10    111
# 11    112
# 12    113
# 13    114
# 14    115
# 15    116
# 16    117
# 17    118
# 18    119
# 19    120
# 20    121
# 21    122
# 22    123
# 23    124
# 24    125
# 25    126
# 26    127
# 27    128
# 28    129
# 29    130
# Name: roll, dtype: int64

# %%
tf = df.iloc[:5,]

# %%
tf
# Out:
#    roll              name class  marks  age
# 0     1   Aditya Kulkarni    FY   85.5   15
# 1     2     Swapnil Joshi    FY   92.1   16
# 2     3  Aniket Deshpande    FY   78.3   16
# 3     4       Gauri Patil    FY   65.8   16
# 4     5      Rohan Sawant    FY   88.2   17

# %%
tf['cgpa'] = tf['marks'] / 10 + 0.27
# Out:
# /tmp/ipykernel_161593/1276032240.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tf['cgpa'] = tf['marks'] / 10 + 0.27

# %%
tf
# Out:
#    roll              name class  marks  age  cgpa
# 0     1   Aditya Kulkarni    FY   85.5   15  8.82
# 1     2     Swapnil Joshi    FY   92.1   16  9.48
# 2     3  Aniket Deshpande    FY   78.3   16  8.10
# 3     4       Gauri Patil    FY   65.8   16  6.85
# 4     5      Rohan Sawant    FY   88.2   17  9.09

# %%
x = ['M','M','M','F','M']

# %%
tf['gender'] = x
tf
# Out:
# /tmp/ipykernel_161593/2959589473.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tf['gender'] = x
#    roll              name class  marks  age  cgpa gender
# 0     1   Aditya Kulkarni    FY   85.5   15  8.82      M
# 1     2     Swapnil Joshi    FY   92.1   16  9.48      M
# 2     3  Aniket Deshpande    FY   78.3   16  8.10      M
# 3     4       Gauri Patil    FY   65.8   16  6.85      F
# 4     5      Rohan Sawant    FY   88.2   17  9.09      M

# %%
# Download -> student-info1.csv and student-info2.csv
# Link: https://mitu.co.in/dataset

# %%
df1 = pd.read_csv('student-info1.csv', names=['roll','name','class','marks','age'])
df2 = pd.read_csv('student-info2.csv')

# %%
df1
# Out:
#    roll           name class  marks  age
# 0    31     Ajit Gawde    FY   68.2   15
# 1    32  Kavita Shelar    FY   81.9   16
# 2    33  Sunil Bhosale    SY   74.5   18
# 3    34  Sarika Kamble    SY   88.0   17
# 4    35   Nilesh Desai    TY   53.4   18
# 5    36    Usha Phadke    TY   91.7   19
# 6    37    Jayant Rane    TY   76.1   18

# %%
newdf = pd.concat([df, df1])

# %%
newdf.shape
# Out:
# (37, 5)

# %%
df2
# Out:
#     roll  gender      city
# 0      1    Male      Pune
# 1      2    Male    Mumbai
# 2      3    Male      Pune
# 3      4  Female    Nagpur
# 4      5    Male    Sangli
# 5      6  Female    Mumbai
# 6      7    Male    Nashik
# 7      8  Female      Pune
# 8      9    Male    Mumbai
# 9     10  Female      Pune
# 10    11  Female    Mumbai
# 11    12    Male      Pune
# 12    13  Female      Pune
# 13    14    Male    Nagpur
# 14    15  Female    Mumbai
# 15    16    Male      Pune
# 16    17  Female    Nashik
# 17    18    Male  Kolhapur
# 18    19  Female    Mumbai
# 19    20    Male    Satara
# 20    21  Female      Pune
# 21    22    Male    Mumbai
# 22    23  Female    Nagpur
# 23    24    Male      Pune
# 24    25  Female      Pune
# 25    26    Male  Amravati
# 26    27  Female    Nashik
# 27    28    Male      Pune
# 28    29  Female      Pune
# 29    30    Male    Nagpur

# %%
newdf = df.merge(df2, on='roll')

# %%
newdf
# Out:
#     roll              name class  marks  age  gender      city
# 0      1   Aditya Kulkarni    FY   85.5   15    Male      Pune
# 1      2     Swapnil Joshi    FY   92.1   16    Male    Mumbai
# 2      3  Aniket Deshpande    FY   78.3   16    Male      Pune
# 3      4       Gauri Patil    FY   65.8   16  Female    Nagpur
# 4      5      Rohan Sawant    FY   88.2   17    Male    Sangli
# 5      6        Pooja More    FY   72.9   16  Female    Mumbai
# 6      7    Shreyas Shinde    FY   95.0   16    Male    Nashik
# 7      8      Sneha Jadhav    FY   58.6   15  Female      Pune
# 8      9      Mahesh Pawar    FY   76.4   16    Male    Mumbai
# 9     10      Priya Chavan    FY   89.7   15  Female      Pune
# 10    11      Amruta Kadam    SY   91.2   17  Female    Mumbai
# 11    12      Sandeep Mane    SY   68.5   17    Male      Pune
# 12    13      Neha Gaikwad    SY   79.9   17  Female      Pune
# 13    14       Sachin Kale    SY   83.1   18    Male    Nagpur
# 14    15      Manisha Rane    SY   94.6   18  Female    Mumbai
# 15    16      Prasad Desai    SY   61.3   17    Male      Pune
# 16    17      Aditi Phadke    SY   77.8   16  Female    Nashik
# 17    18      Sameer Tambe    SY   82.0   18    Male  Kolhapur
# 18    19       Reshma Apte    SY   90.4   17  Female    Mumbai
# 19    20     Kiran Godbole    SY   73.7   16    Male    Satara
# 20    21    Archana Ingale    TY   55.1   19  Female      Pune
# 21    22     Vivek Bhosale    TY   66.9   17    Male    Mumbai
# 22    23     Sonali Kamble    TY   96.2   17  Female    Nagpur
# 23    24    Harshal Shelar    TY   71.5   19    Male      Pune
# 24    25   Prachi Deshmukh    TY   48.8   19  Female      Pune
# 25    26      Milind Patil    TY   84.3   18    Male  Amravati
# 26    27     Rohini Sawant    TY   59.7   18  Female    Nashik
# 27    28   Yogesh Kulkarni    TY   93.0   18    Male      Pune
# 28    29  Supriya Waghmare    TY   67.2   19  Female      Pune
# 29    30      Girish Joshi    TY   75.6   19    Male    Nagpur

# %% [markdown]
# ##### Grouping and aggregation

# %%
df['class'].value_counts()
# Out:
# class
# FY    10
# SY    10
# TY    10
# Name: count, dtype: int64

# %%
newdf['gender'].value_counts()
# Out:
# gender
# Male      16
# Female    14
# Name: count, dtype: int64

# %%
newdf['city'].value_counts()
# Out:
# city
# Pune        12
# Mumbai       7
# Nagpur       4
# Nashik       3
# Sangli       1
# Kolhapur     1
# Satara       1
# Amravati     1
# Name: count, dtype: int64

# %%
gr = df.groupby('class')

# %%
gr.max()
# Out:
#        roll             name  marks  age
# class
# FY       10    Swapnil Joshi   95.0   17
# SY       20     Sandeep Mane   94.6   18
# TY       30  Yogesh Kulkarni   96.2   19

# %%
gr.mean(numeric_only=True)
# Out:
#        roll  marks   age
# class
# FY      5.5  80.25  15.8
# SY     15.5  80.25  17.1
# TY     25.5  71.83  18.3

# %% [markdown]
# ##### Boolean filtering

# %%
df['marks'] > 75
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4      True
# 5     False
# 6      True
# 7     False
# 8      True
# 9      True
# 10     True
# 11    False
# 12     True
# 13     True
# 14     True
# 15    False
# 16     True
# 17     True
# 18     True
# 19    False
# 20    False
# 21    False
# 22     True
# 23    False
# 24    False
# 25     True
# 26    False
# 27     True
# 28    False
# 29     True
# Name: marks, dtype: bool

# %%
x = df[df['marks'] > 75]

# %%
x
# Out:
#     roll              name class  marks  age
# 0      1   Aditya Kulkarni    FY   85.5   15
# 1      2     Swapnil Joshi    FY   92.1   16
# 2      3  Aniket Deshpande    FY   78.3   16
# 4      5      Rohan Sawant    FY   88.2   17
# 6      7    Shreyas Shinde    FY   95.0   16
# 8      9      Mahesh Pawar    FY   76.4   16
# 9     10      Priya Chavan    FY   89.7   15
# 10    11      Amruta Kadam    SY   91.2   17
# 12    13      Neha Gaikwad    SY   79.9   17
# 13    14       Sachin Kale    SY   83.1   18
# 14    15      Manisha Rane    SY   94.6   18
# 16    17      Aditi Phadke    SY   77.8   16
# 17    18      Sameer Tambe    SY   82.0   18
# 18    19       Reshma Apte    SY   90.4   17
# 22    23     Sonali Kamble    TY   96.2   17
# 25    26      Milind Patil    TY   84.3   18
# 27    28   Yogesh Kulkarni    TY   93.0   18
# 29    30      Girish Joshi    TY   75.6   19

# %%
x = df[(df['marks'] > 75) & (df['class'] == 'SY')]

# %%
x
# Out:
#     roll          name class  marks  age
# 10    11  Amruta Kadam    SY   91.2   17
# 12    13  Neha Gaikwad    SY   79.9   17
# 13    14   Sachin Kale    SY   83.1   18
# 14    15  Manisha Rane    SY   94.6   18
# 16    17  Aditi Phadke    SY   77.8   16
# 17    18  Sameer Tambe    SY   82.0   18
# 18    19   Reshma Apte    SY   90.4   17

# %% [markdown]
# ##### Save / export the dataframe

# %%
x.to_csv('output.csv', index=False)
